# %% [markdown]
# Import the libraries needed.

# %%
import os
import sys

from shutil import copyfile
import pandas as pd

# %% [markdown]
# First. clean up the picture field

# %%
ppl_file = 'clean_lab.csv'
df = pd.read_csv(ppl_file)df
# Out:
#             picture   first_name  last_name  \
# 0         vigna.png     Giovanni      Vigna
# 1        chris2.jpg  Christopher    Kruegel
# 2       machiry.png      Aravind    Machiry
# 3          nilo.jpg         Nilo     Redini
# 4   edg_profile.png         Eric  Gustafson
# ..              ...          ...        ...
# 79              NaN        Jason      Berry
# 80       chani.jpeg        Chani     Jindal
# 81              NaN        Keith       Long
# 82              NaN         John     Grosen
# 83              NaN         Paul     Grosen
#
#                                           description  \
# 0   Giovanni Vigna is a Professor in the Departmen...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 79                                                NaN
# 80                                                NaN
# 81                                                NaN
# 82                                                NaN
# 83                                                NaN
#
#                          web_page  visitor               e_mail  alumni  \
# 0   http://www.cs.ucsb.edu/~vigna        0    vigna@cs.ucsb.edu       0
# 1   http://www.cs.ucsb.edu/~chris        0    chris@cs.ucsb.edu       0
# 2      https://machiry.github.io/        0  machiry@cs.ucsb.edu       0
# 3          http://www.badnack.it/        0  badnack@cs.ucsb.edu       0
# 4      http://seclab.cs.ucsb.edu/        0      edg@cs.ucsb.edu       0
# ..                            ...      ...                  ...     ...
# 79                            NaN        0                  NaN       1
# 80                            NaN        0                  NaN       1
# 81                            NaN        0                  NaN       1
# 82                            NaN        0                  NaN       1
# 83                            NaN        0                  NaN       1
#
#     public  current mid_name  rank_id            rank
# 0        1        1      NaN        1         Faculty
# 1        1        1      NaN        1         Faculty
# 2        1        1    Kumar        3    PhD Students
# 3        1        1      NaN        3    PhD Students
# 4        1        1      NaN        3    PhD Students
# ..     ...      ...      ...      ...             ...
# 79       1        0      NaN        6  Master Student
# 80       1        0      NaN        6  Master Student
# 81       1        0      NaN        6  Master Student
# 82       1        0      NaN        7       Undergrad
# 83       1        0      NaN        7       Undergrad
#
# [84 rows x 13 columns]

# %%
df.picture.replace(pd.NA, 'alias.jpeg',inplace=True)
df
# Out:
#             picture   first_name  last_name  \
# 0         vigna.png     Giovanni      Vigna
# 1        chris2.jpg  Christopher    Kruegel
# 2       machiry.png      Aravind    Machiry
# 3          nilo.jpg         Nilo     Redini
# 4   edg_profile.png         Eric  Gustafson
# ..              ...          ...        ...
# 79       alias.jpeg        Jason      Berry
# 80       chani.jpeg        Chani     Jindal
# 81       alias.jpeg        Keith       Long
# 82       alias.jpeg         John     Grosen
# 83       alias.jpeg         Paul     Grosen
#
#                                           description  \
# 0   Giovanni Vigna is a Professor in the Departmen...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 79                                                NaN
# 80                                                NaN
# 81                                                NaN
# 82                                                NaN
# 83                                                NaN
#
#                          web_page  visitor               e_mail  alumni  \
# 0   http://www.cs.ucsb.edu/~vigna        0    vigna@cs.ucsb.edu       0
# 1   http://www.cs.ucsb.edu/~chris        0    chris@cs.ucsb.edu       0
# 2      https://machiry.github.io/        0  machiry@cs.ucsb.edu       0
# 3          http://www.badnack.it/        0  badnack@cs.ucsb.edu       0
# 4      http://seclab.cs.ucsb.edu/        0      edg@cs.ucsb.edu       0
# ..                            ...      ...                  ...     ...
# 79                            NaN        0                  NaN       1
# 80                            NaN        0                  NaN       1
# 81                            NaN        0                  NaN       1
# 82                            NaN        0                  NaN       1
# 83                            NaN        0                  NaN       1
#
#     public  current mid_name  rank_id            rank
# 0        1        1      NaN        1         Faculty
# 1        1        1      NaN        1         Faculty
# 2        1        1    Kumar        3    PhD Students
# 3        1        1      NaN        3    PhD Students
# 4        1        1      NaN        3    PhD Students
# ..     ...      ...      ...      ...             ...
# 79       1        0      NaN        6  Master Student
# 80       1        0      NaN        6  Master Student
# 81       1        0      NaN        6  Master Student
# 82       1        0      NaN        7       Undergrad
# 83       1        0      NaN        7       Undergrad
#
# [84 rows x 13 columns]

# %%
df.to_csv('new.csv')
